# BRP  0.592349  0.902659  0.723687  0.833051  0.964372  0.864668
# BRT  0.919659  0.782612  0.967285  0.987573  0.904601  0.986700
# SLP  0.919804  0.759298  0.961229  0.982256  0.881877  0.978191
# SPP  0.570393  0.866241  0.696353  0.811741  0.959666  0.845971
# SPT  0.875226  0.808810  0.936562  0.978696  0.931131  0.983231
# PRL  1.000000  0.556847  0.978079  0.905421  0.709462  0.886085
# PRP  0.556847  1.000000  0.717468  0.769610  0.828425  0.788056
# PRT  0.978079  0.717468  1.000000  0.952224  0.803776  0.940861
# RJL  0.905421  0.769610  0.952224  1.000000  0.907173  0.997570
# RJP  0.709462  0.828425  0.803776  0.907173  1.000000  0.934108
# RJT  0.886085  0.788056  0.940861  0.997570  0.934108  1.000000

# %%
f = plt.figure(figsize=(8, 8))
plt.matshow(df_corr.corr(), fignum=f.number)
plt.xticks(range(df_corr.select_dtypes(['number']).shape[1]), df_corr.select_dtypes(['number']).columns, fontsize=10, rotation=45)
plt.yticks(range(df_corr.select_dtypes(['number']).shape[1]), df_corr.select_dtypes(['number']).columns, fontsize=10)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)
plt.title('Correlation Matrix', fontsize=16);

# %%
# 1 - Carga das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# 2 - Carga dos dados
df = pd.read_csv("https://raw.githubusercontent.com/diogenesjusto/FIAP-On-Line-Graduation/main/datasets/pib.csv")
 
# 3 - Preparação dos dados
 
# 5 - Construção do modelo
mod = LinearRegression()
mod.fit(x_treino,y_treino)
 
# Cálculo das estatísticas da regressão linear
import statsmodels.api as sm
mod = sm.OLS(y_treino, x_treino).fit()
print(mod.summary())

# 6 - Avaliação do modelo
y_prev = mod.predict(x_teste)
mean_squared_error(y_teste, y_prev)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    PIB   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                          1.226e+04
# Date:                Thu, 04 Aug 2022   Prob (F-statistic):                   2.04e-125
# Time:                        02:19:04   Log-Likelihood:                         -254.90
# No. Observations:                  92   AIC:                                      525.8
# Df Residuals:                      84   BIC:                                      546.0
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# BRP            0.2551      0.277      0.921      0.360      -0.296       0.806
# BRL            0.2199      0.168      1.313      0.193      -0.113       0.553
# BRL            0.2199      0.168      1.313      0.193      -0.113       0.553
# SLP            0.2468      2.351      0.105      0.917      -4.428       4.922
# SPP            0.6877      0.792      0.869      0.387      -0.886       2.262
# SPT           -0.8626      3.104     -0.278      0.782      -7.034       5.309
# RJL           -2.9675      4.514     -0.657      0.513     -11.944       6.009
# RJP           -1.0828      0.958     -1.130      0.262      -2.988       0.822
# RJT            4.1782      5.457      0.766      0.446      -6.674      15.031
# ==============================================================================
# Omnibus:                        1.739   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.419   Jarque-Bera (JB):                1.531
# Skew:                           0.180   Prob(JB):                        0.465
# Kurtosis:                       2.481   Cond. No.                     6.37e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.5e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 19.893975414533536
